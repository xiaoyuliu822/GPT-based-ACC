# %%
import os
import openai
openai.api_key = "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"
openai.File.create(
  file=open("fine_tune_data_prepared.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-vzllXQd75ZTmvqJnWdoiUBhE at 0x2712ae07400> JSON: {
#   "bytes": 109761,
#   "created_at": 1680608056,
#   "filename": "file",
#   "id": "file-vzllXQd75ZTmvqJnWdoiUBhE",
#   "object": "file",
#   "purpose": "fine-tune",
#   "status": "uploaded",
#   "status_details": null
# }

# %%
openai.api_key = "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"
openai.File.list()
# Out:
# <OpenAIObject list at 0x2712d73eb30> JSON: {
#   "data": [
#     {
#       "bytes": 21657,
#       "created_at": 1677030399,
#       "filename": "compiled_results.csv",
#       "id": "file-0HupyS8JZCCbmvDDGbXhnSAy",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 57294,
#       "created_at": 1677029542,
#       "filename": "file",
#       "id": "file-gi6roP5rFSf1Hcnz52JdFDXG",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 65836,
#       "created_at": 1678667669,
#       "filename": "file",
#       "id": "file-LQqyFRM7JUFrvKH3mu7aLIsw",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 65554,
#       "created_at": 1677152472,
#       "filename": "file",
# ...

# %%
openai.api_key = "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"

openai.FineTune.create(
    training_file="file-vzllXQd75ZTmvqJnWdoiUBhE",
    model="davinci"
)
# Out:
# <FineTune fine-tune id=ft-YmnTDcj6o03Di4hx0IY6tqrk at 0x2712acefa90> JSON: {
#   "created_at": 1680608105,
#   "events": [
#     {
#       "created_at": 1680608105,
#       "level": "info",
#       "message": "Created fine-tune: ft-YmnTDcj6o03Di4hx0IY6tqrk",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": null,
#     "n_epochs": 4,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-YmnTDcj6o03Di4hx0IY6tqrk",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-l8jSyOyWopjJBREdDHS0X2Tt",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 109761,
#       "created_at": 1680608056,
#       "filename": "file",
#       "id": "file-vzllXQd75ZTmvqJnWdoiUBhE",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
# ...

# %%
openai.api_key = "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"

openai.FineTune.create(
    training_file="file-vzllXQd75ZTmvqJnWdoiUBhE",
    model="curie"
)
# Out:
# <FineTune fine-tune id=ft-2ym8FDb2FPvm1c7sP0hpJAfu at 0x2712ad70cc0> JSON: {
#   "created_at": 1680608136,
#   "events": [
#     {
#       "created_at": 1680608136,
#       "level": "info",
#       "message": "Created fine-tune: ft-2ym8FDb2FPvm1c7sP0hpJAfu",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": null,
#     "n_epochs": 4,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-2ym8FDb2FPvm1c7sP0hpJAfu",
#   "model": "curie",
#   "object": "fine-tune",
#   "organization_id": "org-l8jSyOyWopjJBREdDHS0X2Tt",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 109761,
#       "created_at": 1680608056,
#       "filename": "file",
#       "id": "file-vzllXQd75ZTmvqJnWdoiUBhE",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
# ...

# %%
openai.api_key = "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"
openai.FineTune.list()
# Out:
# <OpenAIObject list at 0x2712d749400> JSON: {
#   "data": [
#     {
#       "created_at": 1677029665,
#       "fine_tuned_model": "curie:ft-personal-2023-02-22-01-46-39",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-9rxJALED0uHSmwg8b8ptdfGM",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-l8jSyOyWopjJBREdDHS0X2Tt",
#       "result_files": [
#         {
#           "bytes": 21657,
#           "created_at": 1677030399,
#           "filename": "compiled_results.csv",
#           "id": "file-0HupyS8JZCCbmvDDGbXhnSAy",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 57294,
# ...

# %%
openai.api_key = "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"
openai.FineTune.retrieve(id="ft-B4Y6nOOA9LxAq4IXqJEw63Zm")
# Out:
# <FineTune fine-tune id=ft-B4Y6nOOA9LxAq4IXqJEw63Zm at 0x1fef5f62bd0> JSON: {
#   "created_at": 1678667742,
#   "events": [
#     {
#       "created_at": 1678667742,
#       "level": "info",
#       "message": "Created fine-tune: ft-B4Y6nOOA9LxAq4IXqJEw63Zm",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1678668042,
#       "level": "info",
#       "message": "Fine-tune costs $1.63",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1678668042,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1678668045,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1678668191,
#       "level": "info",
#       "message": "Completed epoch 1/4",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1678668223,
# ...

# %%
##openai.api_key = "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"
##openai.FineTune.cancel(id="ft-sNGigRpODzFXaAdZK1b6DT7T")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[29], line 4
#       2 import openai
#       3 openai.api_key = "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"
# ----> 4 openai.FineTune.cancel(id="ft-sNGigRpODzFXaAdZK1b6DT7T")
#
# File ~\anaconda3\envs\PythonforOpenAI\lib\site-packages\openai\api_resources\fine_tune.py:67, in FineTune.cancel(cls, id, api_key, api_type, request_id, api_version, **params)
#      49 @classmethod
#      50 def cancel(
#      51     cls,
#    (...)
#      57     **params,
#      58 ):
#      59     instance, url = cls._prepare_cancel(
#      60         id,
#      61         api_key,
#    (...)
#      65         **params,
#      66     )
# ---> 67     return instance.request("post", url, request_id=request_id)
#
# ...

# %%
##openai.api_key = "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"
##openai.Model.delete("ft-NEqS3nnfJvXFUdfRa7XeHLLu")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[19], line 4
#       2 import openai
#       3 openai.api_key = "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"
# ----> 4 openai.Model.delete("ft-NEqS3nnfJvXFUdfRa7XeHLLu")
#
# File ~\anaconda3\envs\PythonforOpenAI\lib\site-packages\openai\api_resources\abstract\deletable_api_resource.py:38, in DeletableAPIResource.delete(cls, sid, api_type, api_version, **params)
#      34 @classmethod
#      35 def delete(cls, sid, api_type=None, api_version=None, **params):
#      36     url = cls.__prepare_delete(sid, api_type, api_version)
# ---> 38     return cls._static_request(
#      39         "delete", url, api_type=api_type, api_version=api_version, **params
#      40     )
#
# ...
